# %% [markdown]
# # Welcome — Bacteria Strains
#
# Genus (course 3), then species (course 4), and now the resolution level
# underneath both: **strain**. This is the level where the site's running
# example — commensal *E. coli* vs. dangerous *E. coli* — finally gets a
# real, hands-on treatment instead of just being mentioned.

# %% [markdown]
# ## New data, for a real reason
#
# No dataset on this site resolves to strain level — not even the
# bioinformatics course's species-level data. This course introduces one
# small, synthetic, **clearly illustrative** dataset,
# `ecoli_strain_profiles.csv`: 89 synthetic *E. coli* strains, each with
# presence/absence of five real virulence genes and one real antibiotic
# resistance gene, labeled by pathotype. Same honesty rule as every other
# synthetic dataset on this site: real gene names, real biology behind
# each one, invented specific numbers.

# %%
import pandas as pd
df = pd.read_csv("ecoli_strain_profiles.csv")
print(df.shape)
df.head()

# %% [markdown]
# ## Course roadmap
#
# | # | Notebook | Covers |
# |---|---|---|
# | 00 | Welcome | You are here |
# | 01 | What Is a Strain? | Defining the level below species |
# | 02 | Why This Course Needed New Data | The dataset, introduced properly |
# | 03 | *E. coli* Pathotypes, For Real | Shiga toxin, intimin, and the genes behind EHEC/UPEC |
# | 04 | Detecting Strains: Beyond MLST | cgMLST, SNP typing, whole-genome phylogenetics |
# | 05 | Plasmids and Mobile Genetic Elements | Why strain traits can move between organisms |
# | 06 | Antibiotic Resistance as a Strain Trait | Carbapenem resistance, real and high-stakes |
# | 07 | Probiotic Strains Aren't Interchangeable | Clinical evidence is strain-specific |
# | 08 | Building a Strain-Level Presence/Absence Panel | Hands-on, same method as course 2 |
# | 09 | Classifying Strains by Function | A real, cross-validated pathotype classifier |
# | 10 | What Strain Data Still Can't Tell You | Gene expression, regulation, context |
# | 11 | The Full Resolution Ladder | Closing all five courses out |
#
# **Next:** `01_what_is_a_strain.ipynb`.
