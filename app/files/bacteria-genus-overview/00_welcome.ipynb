# %% [markdown]
# # Welcome — Bacteria Genus Overview
#
# The other two courses on this site use genus names as data columns —
# `Bacteroides`, `Prevotella`, `Faecalibacterium`, and about twenty others —
# without ever explaining what most of them actually are. This course goes
# back through them properly, grouped by phylum, with real biology and real
# numbers for each one.

# %% [markdown]
# ## This course reuses data from the other two courses
#
# No new datasets here. Every hands-on notebook loads a CSV from
# `gut-microbiome-under-glass/` or `bioinformatics-of-gut-health/` using a
# relative path one folder up — e.g. `pd.read_csv("../gut-microbiome-under-glass/example_gut_samples.csv")`.
# If you haven't taken either course, that's fine; each notebook explains
# what the data is when it loads it.

# %%
import pandas as pd
df = pd.read_csv("../gut-microbiome-under-glass/example_gut_samples.csv")
print("Confirmed: this course can read the other courses' data.", df.shape)

# %% [markdown]
# ## Course roadmap
#
# | # | Notebook | Covers |
# |---|---|---|
# | 00 | Welcome | You are here |
# | 01 | What Is a Genus, Anyway? | Taxonomic ranks, naming, why some genus names have brackets |
# | 02 | Bacteroidetes I | *Bacteroides* & *Prevotella* — the diet-driven pair |
# | 03 | Bacteroidetes II | *Alistipes* & *Parabacteroides* |
# | 04 | Firmicutes I | *Faecalibacterium*, *Roseburia*, *Eubacterium* — the butyrate producers |
# | 05 | Firmicutes II | *Ruminococcus*, *Blautia*, *Dorea*, *Lachnospira*, *Oscillospira* |
# | 06 | Actinobacteria | *Bifidobacterium* |
# | 07 | Proteobacteria | *Escherichia* & *Klebsiella* — the opportunists |
# | 08 | Verrucomicrobia | *Akkermansia* |
# | 09 | Fusobacteria & Friends | *Fusobacterium*, *Veillonella*, *Dialister* |
# | 10 | Comparing Genus Profiles | All three datasets, side by side |
# | 11 | Genus Isn't the Whole Story | Limits of genus-level resolution, what's next |
#
# **Next:** `01_what_is_a_genus_anyway.ipynb`.
