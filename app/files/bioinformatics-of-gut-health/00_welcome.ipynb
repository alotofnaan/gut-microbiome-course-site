# %% [markdown]
# # Welcome — Bioinformatics of Gut Health
#
# This course is about the **computational pipeline** behind gut-health
# tools like GMWI2 — from a raw DNA read out of a sequencer, all the way to
# a single number that claims to say something about your health. It runs
# entirely in your browser, same as the other course on this site: real
# Python, via Pyodide, no installs, no account.

# %% [markdown]
# ## How this course is different from "The Gut Microbiome, Under Glass"
#
# That course is about the **biology and statistics** of gut microbiome
# data — what the bacteria do, how to test whether a difference is real.
# This course is about the **pipeline that produces the data** — the actual
# software and algorithms, including one specific real 2024 tool (GMWI2) in
# enough depth to actually understand how it works, not just what it's
# called. You don't need to have taken the other course first, but a few
# notebooks cross-reference it.

# %% [markdown]
# ## The pattern
#
# Same loop as always: **Read** → **Run** → **Modify** (🔧 YOUR TURN) →
# **Explain** (in your own words). Five of the eight notebooks here are
# genuinely hands-on — you'll parse real sequence data, build a classifier,
# and compute the same kind of score GMWI2 computes, all with real code.
# Three are conceptual walkthroughs (clearly labeled) for the parts of the
# pipeline that need compiled, conda-based tools no browser can run.

# %%
print("Real Python, in your browser. Let's start with the rawest material there is: a DNA sequence.")

# %% [markdown]
# ## Course roadmap
#
# | # | Notebook | Type | Covers |
# |---|---|---|---|
# | 00 | Welcome | — | You are here |
# | 01 | Reading Raw Sequence Data | Hands-on | FASTA/FASTQ, Biopython, what a "read" actually is |
# | 02 | From Reads to a Taxonomy Table | Conceptual | QC, MetaPhlAn3, why GMWI2 needs shotgun data |
# | 03 | From Abundance to Presence/Absence | Hands-on | Binarizing a species table, by hand |
# | 04 | Health- vs. Disease-Associated Species | Hands-on | A simplified log-ratio health score |
# | 05 | Training a Health Classifier | Hands-on | Lasso logistic regression, cross-validation, scikit-learn |
# | 06 | Running GMWI2 for Real | Conceptual | The real CLI, real output files, real citation |
# | 07 | Limits, Critiques, What's Next | Conceptual | What GMWI2 can't tell you, and where the field goes next |
#
# **Next:** `01_reading_raw_sequence_data.ipynb`.
