# %% [markdown]
# # Welcome — Species-Level Resolution
#
# The genus course closed by admitting genus isn't the whole story. This
# course is the next rung down: what a **species** actually is in
# bacteria, why it's genuinely harder to define than in animals, and what
# you can see once you have data that actually resolves to that level.

# %% [markdown]
# ## This course reuses the bioinformatics course's data
#
# `toy_species_abundance.csv` (from *Bioinformatics of Gut Health*) has
# been sitting there the whole time with species-level column names —
# `Faecalibacterium_prausnitzii`, `Akkermansia_muciniphila`, and others.
# This course is the first to actually treat it as species-level data
# rather than just a presence/absence table for a classifier.

# %%
import pandas as pd
df = pd.read_csv("../bioinformatics-of-gut-health/toy_species_abundance.csv")
print(df.shape)
print(list(df.columns))

# %% [markdown]
# ## Course roadmap
#
# | # | Notebook | Covers |
# |---|---|---|
# | 00 | Welcome | You are here |
# | 01 | What Makes a Species? | ANI, why 16S can't resolve this, species as a convention |
# | 02 | This Course's Data, at Species Resolution | Re-examining familiar genera one level down |
# | 03 | The *Faecalibacterium* Split | Real recent taxonomic revision |
# | 04 | *Bifidobacterium* Species | Infant- vs. adult-associated species |
# | 05 | *Akkermansia* Beyond *muciniphila* | The genus has more than one member |
# | 06 | *E. coli* and the Pathotype Problem | The bridge to strains |
# | 07 | *Bacteroides* & *Prevotella* Species | Conceptual — no dataset here resolves this far |
# | 08 | How Species Boundaries Are Measured | ANI, MLST, whole-genome methods |
# | 09 | Is "Species" a Natural Category for Bacteria? | The contested species concept |
# | 10 | Species-Level Diversity, Hands-On | Shannon/Simpson at species resolution |
# | 11 | Species Isn't the End Either | Closing, and the hand-off to strains |
#
# **Next:** `01_what_makes_a_species.ipynb`.
